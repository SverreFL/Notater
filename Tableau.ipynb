# %% [markdown]
# # Workspace

# %% [markdown]
# 1. Worksheet
# 2. Dashboard
# 3. Story

# %% [markdown]
# Workspace består av *shelves*, *cards* og *view*. Har én workspace per sheet der jeg lager én visualisering. Kombinerer flere sheets for å lage dashboard eller story.

# %% [markdown]
# Bruker drop down menyer til å formatere

# %% [markdown]
# Drar kolonner til *shelves* og *cards*.. Kan eventuelt få det automatisk generert gjennom *show me* menyen

# %% [markdown]
# Kan gjøre mye dataprep inne i tableau

# %% [markdown]
# ## filters

# %% [markdown]
# show filter for å gjøre interaktiv
#
# kan også gjøre dette på andre variabler som ikke er i filter..

# %% [markdown]
# # Data

# %% [markdown]
# Deler inn i *dimensions* (kvalitativ) og *measures* (kvantitiativ). Dimensions styrer nivå av aggregering. Kan lage eksplisitt hierarki.. hm.

# %% [markdown]
# Kan bruke calculated field fra drop down menu. Kan bruke kode til å beskrive logikk... litt usikker på dette
